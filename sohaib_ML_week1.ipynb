# %% [markdown]
# <a href="https://colab.research.google.com/github/Sohaibsul/velocity_ML_intership/blob/main/sohaib_ML_week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **WEEK 1: Exploratory Data Analysis (EDA)**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # **Load Dataset**

# %%
from google.colab import files
upload = files.upload()
df = pd.read_csv('tested.csv')
# Out:
#      <input type="file" id="files-d4029ae0-6e83-48b3-a66f-f8dd4b43faf3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4029ae0-6e83-48b3-a66f-f8dd4b43faf3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# # **Check Columns, Data Types, and Info**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %% [markdown]
# # **Get Summary Statistics**

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                      Name   Sex  \
# count    418.000000  418.000000  418.000000                       418   418
# unique          NaN         NaN         NaN                       418     2
# top             NaN         NaN         NaN  Peter, Master. Michael J  male
# freq            NaN         NaN         NaN                         1   266
# mean    1100.500000    0.363636    2.265550                       NaN   NaN
# std      120.810458    0.481622    0.841838                       NaN   NaN
# min      892.000000    0.000000    1.000000                       NaN   NaN
# 25%      996.250000    0.000000    1.000000                       NaN   NaN
# 50%     1100.500000    0.000000    3.000000                       NaN   NaN
# 75%     1204.750000    1.000000    3.000000                       NaN   NaN
# max     1309.000000    1.000000    3.000000                       NaN   NaN
#
# ...

# %% [markdown]
# # **Check Null (Missing) Values**

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# # **Data Cleaning**

# %%
df.drop(columns=['PassengerId', 'Name', 'Ticket', 'Cabin'], inplace=True, errors='ignore')

# %% [markdown]
# Handle Missing Values

# %%
# fill missing values
if df['Age'].isnull().sum() > 0:
    df['Age'] = df['Age'].fillna(df['Age'].median())

if df['Embarked'].isnull().sum() > 0:
    df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        1
# Embarked    0
# dtype: int64

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# Survival by Gender

# %%
sns.countplot(data=df, x='Sex', hue='Survived')
plt.title('Survival by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # **Age Distribution**

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['Age'], bins=30, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # **Survival by Class**

# %%
sns.countplot(data=df, x='Pclass', hue='Survived')
plt.title('Survival by Passenger Class')
plt.xlabel('Class')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # **Save Cleaned Dataset**

# %%
df.to_csv('cleaned_tested.csv', index=False)

# %% [markdown]
# # **Summary**

# %% [markdown]
# ### Week 1 Summary for Custom Dataset
#
# - **Dataset**: Custom Titanic dataset (`tested.csv`)
# - **Cleaning Steps**:
#   - Dropped unused columns: PassengerId, Name, Ticket, Cabin.
#   - Handled missing values in Age and Embarked.
# - **Insights**:
#   - Female passengers had a higher survival rate.
#   - Majority of passengers were between 20–40 years old.
#   - First-class passengers had the highest survival rate.
# - **Output**: Cleaned dataset saved as `cleaned_tested.csv`
